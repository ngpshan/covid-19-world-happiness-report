# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('unemployment_data_us_state2020.csv')
df
# Out:
#              State Month  Unemployment_Rate      Date
# 0          Alabama   Jan                2.7  Jan-2020
# 1           Alaska   Jan                6.0  Jan-2020
# 2          Arizona   Jan                4.5  Jan-2020
# 3         Arkansas   Jan                3.5  Jan-2020
# 4       California   Jan                3.9  Jan-2020
# ..             ...   ...                ...       ...
# 151     Washington   Mar                5.1  Mar-2020
# 152  West Virginia   Mar                6.1  Mar-2020
# 153      Wisconsin   Mar                3.4  Mar-2020
# 154        Wyoming   Mar                3.7  Mar-2020
# 155    Puerto Rico   Mar                NaN  Mar-2020
#
# [156 rows x 4 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head(12)
# Out:
#           State Month  Unemployment_Rate       Date
# 0       Alabama   Jan                2.7 2020-01-01
# 1        Alaska   Jan                6.0 2020-01-01
# 2       Arizona   Jan                4.5 2020-01-01
# 3      Arkansas   Jan                3.5 2020-01-01
# 4    California   Jan                3.9 2020-01-01
# 5      Colorado   Jan                2.5 2020-01-01
# 6   Connecticut   Jan                3.7 2020-01-01
# 7      Delaware   Jan                4.0 2020-01-01
# 8          D.C.   Jan                5.2 2020-01-01
# 9       Florida   Jan                2.8 2020-01-01
# 10      Georgia   Jan                3.1 2020-01-01
# 11       Hawaii   Jan                2.7 2020-01-01

# %%
df.shape
# Out:
# (156, 4)

# %%
df['State'].unique
# Out:
# <bound method Series.unique of 0            Alabama
# 1             Alaska
# 2            Arizona
# 3           Arkansas
# 4         California
#            ...
# 151       Washington
# 152    West Virginia
# 153        Wisconsin
# 154          Wyoming
# 155      Puerto Rico
# Name: State, Length: 156, dtype: object>

# %% [markdown]
# ### Line charts work best when there is a logical connection between adjacent points.  In our case, that connection is the flow of time.

# %%
#first_twelve = df[0:12]
plt.plot(df['Date'], df['Unemployment_Rate'])

# %%
plt.plot(df['Date'], df['Unemployment_Rate'])
plt.xticks(rotation=90)
plt.xlabel('Month')
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')
# Out:
# Text(0.5, 1.0, 'Monthly Unemployment Trends, 1948')
